# %%
import os
import random
import subprocess
import matplotlib.pyplot as plt
import cv2
import numpy as np
import itertools

# %%
# Set the path to the folder containing images
image_folder = '/home/huandong/CV/dataset_clean/images/val/'

# Get all image files from the folder
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]

num_pics=20
selected_images = random.sample(image_files, num_pics)

# %%
# Path to your detect.py script
detect_script = '/home/huandong/CV/yolov9/detect.py'

# Path to your trained model weights
model_weights = '/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'

# Device configuration (use 'mps' for Apple Silicon GPU, 'cpu' or 'cuda' for others)
device = '0'

# Loop through selected images and run detection
for image in selected_images:
    image_path = os.path.join(image_folder, image)
    output_folder_name = 'val_pictures'  # you might want to adjust this for images
    cmd = f'python {detect_script} --weights {model_weights} --exist-ok --source {image_path} --name {output_folder_name} --device {device}'
    subprocess.run(cmd, shell=True)
# Out:
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/ZzMoT0UahKrIDZJDqu0PqA.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/ZzMoT0UahKrIDZJDqu0PqA.jpg: 480x640 (no detections), 76.5ms
# Speed: 0.3ms pre-process, 76.5ms inference, 18.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/q9WfRpPAmNGYC6o1iKII7Q.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/q9WfRpPAmNGYC6o1iKII7Q.jpg: 480x640 1 R-SpeedLimit, 71.8ms
# Speed: 0.3ms pre-process, 71.8ms inference, 61.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/fget-mb-CtXHIls_3SQn8A.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/fget-mb-CtXHIls_3SQn8A.jpg: 480x640 (no detections), 74.7ms
# Speed: 0.3ms pre-process, 74.7ms inference, 8.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/dH--9eXWNEg4y3E3gZuDaA.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/dH--9eXWNEg4y3E3gZuDaA.jpg: 384x640 1 W-PedestrianCrossing, 70.3ms
# Speed: 0.2ms pre-process, 70.3ms inference, 58.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/AgIuo84buewjgiXQboJ4SA.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/AgIuo84buewjgiXQboJ4SA.jpg: 480x640 1 W-PedestrianCrossing, 72.9ms
# Speed: 0.2ms pre-process, 72.9ms inference, 47.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/oNz2-jTx3fh_1HzX_7etTw.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/oNz2-jTx3fh_1HzX_7etTw.jpg: 480x640 1 R-SpeedLimit, 72.5ms
# Speed: 0.3ms pre-process, 72.5ms inference, 44.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/NQUFFViqz7GFmrbUv3wIHA.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/NQUFFViqz7GFmrbUv3wIHA.jpg: 384x640 4 R-SpeedLimits, 71.0ms
# Speed: 0.2ms pre-process, 71.0ms inference, 53.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/KibR92mZlR8Lrk4tNPnE9Q.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/KibR92mZlR8Lrk4tNPnE9Q.jpg: 480x640 1 R-Stop, 73.2ms
# Speed: 0.2ms pre-process, 73.2ms inference, 56.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/AxA7EJmAcr4x4KtgUHrx1A.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/AxA7EJmAcr4x4KtgUHrx1A.jpg: 640x480 1 R-Stop, 71.5ms
# Speed: 0.2ms pre-process, 71.5ms inference, 63.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/oBmHpLpN42USWkYTecYF-w.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/oBmHpLpN42USWkYTecYF-w.jpg: 384x640 1 W-SchoolZone, 69.7ms
# Speed: 0.2ms pre-process, 69.7ms inference, 55.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/iWD_-mKFP2OL4PF1z96wDw.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/iWD_-mKFP2OL4PF1z96wDw.jpg: 480x640 2 R-NoEntrys, 73.5ms
# Speed: 0.3ms pre-process, 73.5ms inference, 53.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/8c5wZFmVmUqU3dU1kvpQkQ.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/8c5wZFmVmUqU3dU1kvpQkQ.jpg: 480x640 1 R-SpeedLimit, 1 W-RoadNarrows, 72.1ms
# Speed: 0.3ms pre-process, 72.1ms inference, 55.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/pcZgCJp0skoBTCwxYBqpbg.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/pcZgCJp0skoBTCwxYBqpbg.jpg: 384x640 1 W-CurveLeft, 71.6ms
# Speed: 0.3ms pre-process, 71.6ms inference, 54.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/9hwE5Jm5qgFJfCf1wpfjZw.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/9hwE5Jm5qgFJfCf1wpfjZw.jpg: 480x640 2 W-SteepAscents, 71.9ms
# Speed: 0.2ms pre-process, 71.9ms inference, 53.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/u9lg1aqXm_UmrTn6eK4H_w.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/u9lg1aqXm_UmrTn6eK4H_w.jpg: 480x640 1 R-SpeedLimit, 1 R-NoOvertaking, 71.3ms
# Speed: 0.2ms pre-process, 71.3ms inference, 61.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/jLF4O1Nne-zHsxXzf5slHg.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/jLF4O1Nne-zHsxXzf5slHg.jpg: 480x640 (no detections), 71.6ms
# Speed: 0.2ms pre-process, 71.6ms inference, 8.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/JPW64gnK-IoUDR9nl5LB5g.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/JPW64gnK-IoUDR9nl5LB5g.jpg: 480x640 1 R-SpeedLimit, 73.4ms
# Speed: 0.3ms pre-process, 73.4ms inference, 56.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/N5jB1q1snWhTy4MhbJHL3A.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/N5jB1q1snWhTy4MhbJHL3A.jpg: 480x640 1 W-SchoolZone, 71.2ms
# Speed: 0.2ms pre-process, 71.2ms inference, 44.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/7gEEKEbN400utMdBudP6XA.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/7gEEKEbN400utMdBudP6XA.jpg: 480x640 (no detections), 72.0ms
# Speed: 0.2ms pre-process, 72.0ms inference, 11.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures
# detect: weights=['/home/huandong/CV/yolov9/runs/train/exp6/weights/best.pt'], source=/home/huandong/CV/dataset_clean/images/val/eRffyeAvPnyiyh4RSukF5w.jpg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=val_pictures, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.7 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24245MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25436403 parameters, 0 gradients, 102.6 GFLOPs
# image 1/1 /home/huandong/CV/dataset_clean/images/val/eRffyeAvPnyiyh4RSukF5w.jpg: 480x640 (no detections), 74.0ms
# Speed: 0.3ms pre-process, 74.0ms inference, 8.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov9/runs/detect/val_pictures

# %%
# %matplotlib inline
fig, ax = plt.subplots(3,3, figsize=(10,10))
plt.subplots_adjust(wspace=0, hspace=0)


imgnames = os.listdir('/home/huandong/CV/yolov9/runs/detect/val_pictures')

for i,j in itertools.product(range(3), range(3)):
    imgname = np.random.choice(imgnames)
    img = cv2.imread(f'/home/huandong/CV/yolov9/runs/detect/val_pictures/{imgname}')
    ax[i, j].axis('off')
    ax[i,j].imshow(cv2.cvtColor(np.squeeze(img), cv2.COLOR_BGR2RGB))
